# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setAppName("Write to file")

# %%
sc = SparkContext.getOrCreate(conf)

# %%
fileRDD = sc.textFile('/FileStore/tables/lines.txt')

# %%
#fileRDD.saveAsTextFile('/FileStore/tables/output/lines.txt/1')
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <command-918085852257550> in <module>
# ----> 1 fileRDD.saveAsTextFile('/FileStore/tables/output/lines.txt')
#
# /databricks/spark/python/pyspark/rdd.py in saveAsTextFile(self, path, compressionCodecClass)
#    1861             self.ctx._jvm.PythonRDD.saveAsTextFileImpl(keyed._jrdd, path, compressionCodecClass)
#    1862         else:
# -> 1863             self.ctx._jvm.PythonRDD.saveAsTextFileImpl(keyed._jrdd, path)
#    1864
#    1865     # Pair functions
#
# /databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ...

# %%
fileRDD.getNumPartitions()
# Out:
# Out[8]: 2
